# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('quikr_car.csv')

# %%
df.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
df.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
df.dtypes
# Out:
# name          object
# company       object
# year          object
# Price         object
# kms_driven    object
# fuel_type     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
df['company'].value_counts()
# Out:
# Maruti        235
# Hyundai       145
# Mahindra      100
# Tata           74
# Honda          61
# Toyota         39
# Chevrolet      35
# Renault        34
# Ford           31
# Volkswagen     20
# Skoda          13
# Audi           11
# Datsun          8
# Mini            8
# BMW             8
# Nissan          6
# Commercial      6
# Mercedes        6
# Mitsubishi      6
# Force           4
# Fiat            4
# tata            3
# Hindustan       3
# I               3
# MARUTI          2
# urgent          2
# Used            2
# Jaguar          2
# Sale            2
# Well            1
# Any             1
# TATA            1
# sell            1
# scratch         1
# 9               1
# 7               1
# all             1
# Land            1
# 2012            1
# i               1
# Volvo           1
# very            1
# Jeep            1
# Swift           1
# URJENT          1
# selling         1
# Yamaha          1
# Tara            1
# Name: company, dtype: int64

# %%
df[df['company']=='Maruti']
# Out:
#                                       name company  year          Price  \
# 2               Maruti Suzuki Alto 800 Vxi  Maruti  2018  Ask For Price
# 9           Maruti Suzuki Alto K10 VXi AMT  Maruti  2015       2,50,000
# 11              Maruti Suzuki Stingray VXi  Maruti  2015       3,15,000
# 19                  Maruti Suzuki Alto 800  Maruti  2014       1,60,000
# 22              Maruti Suzuki Alto 800 Vxi  Maruti  2015         75,000
# ..                                     ...     ...   ...            ...
# 876                    Maruti Suzuki Dzire  Maruti  2016       4,50,000
# 879          Maruti Suzuki Alto LXi BS III  Maruti  2005         95,000
# 880     Maruti Suzuki Swift Dzire Tour VDi  Maruti  2009       2,50,000
# 882  Maruti Suzuki Alto 800 Select Variant  Maruti  2015  Ask For Price
# 883             Maruti Suzuki Ritz VXI ABS  Maruti  2011       2,70,000
#
#      kms_driven fuel_type
# 2    22,000 kms    Petrol
# 9    60,000 kms    Petrol
# 11   30,000 kms    Petrol
# 19   35,550 kms    Petrol
# 22   39,000 kms    Petrol
# ..          ...       ...
# 876   2,500 kms    Diesel
# 879  65,000 kms    Petrol
# 880  51,000 kms    Diesel
# 882  70,000 kms    Petrol
# 883  50,000 kms    Petrol
#
# [235 rows x 6 columns]

# %%
df['fuel_type'].value_counts()
# Out:
# Petrol    440
# Diesel    395
# LPG         2
# Name: fuel_type, dtype: int64

# %%
df[(df['company']=='Volkswagen') & (df['year']>'2015')]
# Out:
#                                              name     company  year  \
# 86   Volkswagen Vento Highline Plus 1.5 Diesel AT  Volkswagen  2019
# 849                Volkswagen Polo Highline1.2L P  Volkswagen  2017
#
#          Price  kms_driven fuel_type
# 86   12,00,000   3,600 kms    Diesel
# 849   5,25,000  45,000 kms    Petrol

# %%
df[df['company'] == 'Mercedes']
# Out:
#                                            name   company  year      Price  \
# 231       Mercedes Benz GLA Class 200 CDI Sport  Mercedes  2015  20,00,000
# 235           Mercedes Benz B Class B180 Sports  Mercedes  2014  14,00,000
# 399       Mercedes Benz C Class 200 CDI Classic  Mercedes  2002   3,99,000
# 434    Mercedes Benz A Class A 180 Sport Petrol  Mercedes  2013  15,00,000
# 698  Mercedes Benz C Class C 220 CDI Avantgarde  Mercedes  2009  12,25,000
# 878              Mercedes Benz C Class 200 K MT  Mercedes  2006   5,00,001
#
#      kms_driven fuel_type
# 231  20,000 kms    Diesel
# 235  31,000 kms    Petrol
# 399  41,000 kms    Petrol
# 434  14,000 kms    Petrol
# 698  76,000 kms    Diesel
# 878  15,000 kms    Petrol
