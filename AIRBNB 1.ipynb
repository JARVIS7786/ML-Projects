# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("C:/Users/yuvra/Downloads/airbnb prices.csv")

# %%
df.tail(5)
# Out:
#         room_id  survey_id    host_id     room_type  country       city  \
# 18718  17789893       1476   47501089  Private room      NaN  Amsterdam
# 18719  16877166       1476   67093870  Private room      NaN  Amsterdam
# 18720  19859427       1476   29724632  Private room      NaN  Amsterdam
# 18721  17132164       1476  115156569  Private room      NaN  Amsterdam
# 18722   7605782       1476   39503013  Private room      NaN  Amsterdam
#
#        borough             neighborhood  reviews  overall_satisfaction  \
# 18718      NaN          Bijlmer Centrum       10                   5.0
# 18719      NaN          Bijlmer Centrum        6                   5.0
# 18720      NaN  Geuzenveld / Slotermeer        0                   0.0
# 18721      NaN             Centrum West       13                   4.5
# 18722      NaN             Centrum West      113                   4.5
#
#        accommodates  bedrooms  bathrooms  price  minstay  \
# ...

# %%
df.describe()
# Out:
#             room_id  survey_id       host_id  country  borough       reviews  \
# count  1.872300e+04    18723.0  1.872300e+04      0.0      0.0  18723.000000
# mean   1.120568e+07     1476.0  3.577612e+07      NaN      NaN     16.741548
# std    6.082192e+06        0.0  3.758103e+07      NaN      NaN     33.522630
# min    2.818000e+03     1476.0  2.234000e+03      NaN      NaN      0.000000
# 25%    6.050608e+06     1476.0  7.140879e+06      NaN      NaN      2.000000
# 50%    1.228287e+07     1476.0  1.988641e+07      NaN      NaN      6.000000
# 75%    1.661084e+07     1476.0  5.202680e+07      NaN      NaN     17.000000
# max    2.000373e+07     1476.0  1.418319e+08      NaN      NaN    532.000000
#
#        overall_satisfaction  accommodates      bedrooms  bathrooms  \
# count          18723.000000  18723.000000  18723.000000        0.0
# mean               3.301127      2.922021      1.430380        NaN
# std                2.213558      1.327524      0.879019        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18723 entries, 0 to 18722
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   room_id               18723 non-null  int64
#  1   survey_id             18723 non-null  int64
#  2   host_id               18723 non-null  int64
#  3   room_type             18723 non-null  object
#  4   country               0 non-null      float64
#  5   city                  18723 non-null  object
#  6   borough               0 non-null      float64
#  7   neighborhood          18723 non-null  object
#  8   reviews               18723 non-null  int64
#  9   overall_satisfaction  18723 non-null  float64
#  10  accommodates          18723 non-null  int64
#  11  bedrooms              18723 non-null  float64
#  12  bathrooms             0 non-null      float64
#  13  price                 18723 non-null  float64
#  14  minstay               0 non-null      float64
# ...

# %%
df.isnull().sum()
# Out:
# room_id                     0
# survey_id                   0
# host_id                     0
# room_type                   0
# country                 18723
# city                        0
# borough                 18723
# neighborhood                0
# reviews                     0
# overall_satisfaction        0
# accommodates                0
# bedrooms                    0
# bathrooms               18723
# price                       0
# minstay                 18723
# name                       52
# last_modified               0
# latitude                    0
# longitude                   0
# location                    0
# dtype: int64

# %%
df.drop(['country','borough','bathrooms','minstay'],axis =1,inplace =True)

# %%
df.head(4)
# Out:
#     room_id  survey_id   host_id    room_type       city  \
# 0  10176931       1476  49180562  Shared room  Amsterdam
# 1   8935871       1476  46718394  Shared room  Amsterdam
# 2  14011697       1476  10346595  Shared room  Amsterdam
# 3   6137978       1476   8685430  Shared room  Amsterdam
#
#               neighborhood  reviews  overall_satisfaction  accommodates  \
# 0  De Pijp / Rivierenbuurt        7                   4.5             2
# 1             Centrum West       45                   4.5             4
# 2          Watergraafsmeer        1                   0.0             3
# 3             Centrum West        7                   5.0             4
#
#    bedrooms  price                                            name  \
# 0       1.0  156.0        Red Light/ Canal view apartment (Shared)
# 1       1.0  126.0  Sunny and Cozy Living room in quite neighbours
# 2       1.0  132.0                                       Amsterdam
# ...

# %%
df.columns
# Out:
# Index(['room_id', 'survey_id', 'host_id', 'room_type', 'city', 'neighborhood',
#        'reviews', 'overall_satisfaction', 'accommodates', 'bedrooms', 'price',
#        'name', 'last_modified', 'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
df.drop(['latitude','longitude'],axis= 1,inplace =True)

# %%
host_areas=df.groupby(['host_id','neighborhood'])['reviews'].max().reset_index()

# %%
host_areas
# Out:
#          host_id                            neighborhood  reviews
# 0           2234                  De Baarsjes / Oud West        1
# 1           3159  Oostelijk Havengebied / Indische Buurt      203
# 2           3806                              Westerpark       24
# 3           5988               Noord-West / Noord-Midden       80
# 4           7924                            Centrum West        0
# ...          ...                                     ...      ...
# 16430  141658022               Noord-West / Noord-Midden        0
# 16431  141665148                            Centrum Oost        0
# 16432  141747815                 De Pijp / Rivierenbuurt        0
# 16433  141749109                            Centrum West        0
# 16434  141831915  Oostelijk Havengebied / Indische Buurt        0
#
# [16435 rows x 3 columns]

# %%
host_areas.sort_values(by="reviews",ascending = False).head(7)
# Out:
#       host_id            neighborhood  reviews
# 63     186729            Centrum West      532
# 463    935723  De Baarsjes / Oud West      465
# 160    336950            Centrum West      463
# 364    732783           Bos en Lommer      452
# 1338  2586026            Centrum Oost      447
# 1956  3556421            Centrum West      443
# 4510  7867565            Centrum West      443
